# %% [markdown]
# 7.4 Make a list called things with these three strings as elements:
#  "mozzarella", "cinderella", "salmonella"

# %%
ella_list: list = ["mozzarella", "cinderella", "salmonella"]
print(ella_list)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %% [markdown]
# 7.5 Capitalize the element in things that refers to a person and then print the list. Did it change the element in the list?

# %%
ella_list[1] = ella_list[1].capitalize()
print(ella_list)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# 7.6 Make the cheesy element of things all uppercase and then print the list

# %%
ella_list[0] = ella_list[0].upper()
print(ella_list)
# Out:
# ['MOZZARELLA', 'cinderella', 'salmonella']

# %% [markdown]
# 7.7 Delete the disease element from things, collect your Nobel Prize, and print the list

# %%
del ella_list[2]
print("Nobel Prize Obtained")
print(ella_list)
# Out:
# Nobel Prize Obtained
# ['MOZZARELLA', 'cinderella']

# %% [markdown]
# 9.1 Define a function called good() that returns the following list ['Harry', 'Ron', 'Hermione']

# %%
golden_trio = ['Harry', 'Ron', 'Hermione']

def good(list):
    print(list)

good(golden_trio)
# Out:
# ['Harry', 'Ron', 'Hermione']

# %% [markdown]
# 9.2 Define a generator function called get_odds() that returns the odd numbers from ranger(10). Use a for loop to find and print the third value returned.

# %%
def gen_odds(r):
    for num in range(10):
        if num % 2 == 1:
            yield num
            
            
count = 0

for value in gen_odds(count):
    count += 1
    if count == 3:
        print(value)
        break
# Out:
# 5
