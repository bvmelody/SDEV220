# %% [markdown]
# Pandas Assignment:

# %%
import pandas as pd

# %%
df = pd.read_csv('relco_church.csv')

# %%
#tempdict = {'coll'L [1,2,3], 'col2':[4,5,6]}

# %% [markdown]
# Read
# 2.1 Show top 5 and Bottom 5 Rows

# %%
df.head(10)
