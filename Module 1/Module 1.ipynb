# %% [markdown]
# # Chapter 3 - Things to Do
#
# **Table of Conetns**
#
# - [3.1](#31---number-of-seconds-in-an-hour)

# %% [markdown]
# # Module 1
#
# # Assignment 1
#
# # 3.1
#
# How many seconds are in an hour? Use the interactive as a calculator and multiplu the number of seconds in a minute (60) by the number of minutes in an hour (also 60).

# %%
my_int: int = 5
my_float: float = 5.5
my_str: str= 'my string'
my_str2: str = f"my string2: {my_float}"
my_dictionary: dict = {1: 'one', 2: 'two'}
my_tuple: tuple = (1, 2, 3, 4)
my_list: list = [1,2,3,4]
my_list.append(5)

3 + 4
4 - 2
6 / 3
6 % 3
6 // 5
6 * 5
2 ** 4
# Out:
# 1

# %%
seconds_in_min: int = 60
minutes_in_hour: int = 60

seconds_in_hour = seconds_in_min * minutes_in_hour
print(seconds_in_hour)
# Out:
# 3600

# %% [markdown]
# # 3.2
#
# Assign the result from the previous task (seconds in an hour) to a variable called seconds_per_hour.

# %%
seconds_per_hour: int = seconds_in_hour
print(seconds_per_hour)
# Out:
# 3600

# %% [markdown]
# # 3.3
#
# # How many seconds are in a day? Use your seconds_per_hour variable.

# %%
print(seconds_per_hour * 24)
# Out:
# 86400

# %% [markdown]
# # 3.4
#
# # Caculate seconds per day again, but this time save the result in a variable called seconds_per_day.

# %%
hours_in_day: int = 24
seconds_per_day: int = hours_in_day * seconds_per_hour
print(seconds_per_day)
# Out:
# 86400

# %% [markdown]
# # 3.5
#
# # Divide seconds_per_day by seconds_per_hour. Use floating-point (/) division.

# %%
print(seconds_per_day / seconds_in_hour)
# Out:
# 24.0

# %% [markdown]
# # 3.6
#
# # Divide seconds_per_day by seconds_per_hour, using integer (//) division. Did this number agree with the floating-point value from the previous question, aside from the final .0?

# %%
print(seconds_per_day // seconds_per_hour)
# Out:
# 24
